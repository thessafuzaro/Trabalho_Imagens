# %% [markdown]
# <a href="https://colab.research.google.com/github/thessafuzaro/Trabalho_Imagens/blob/main/Recycle_018_Cassificacao_Imagens_Alpaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Segundo Projeto de redes neurais
#Processamento de Imagens
#Aluna: Thessa Fuzaro Mendes
#Data: 03/07/2021

# %%
from matplotlib import pyplot as plt  # para fazer graficos
import numpy as np
import pandas as pd
import cv2  #biblioteca que trabalha com imagens
import random
import zipfile  #para trabalhar com arquivos zip
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# %%
#Importando os arquivos que estão no googledrive
# !gdown --id 1X7ZqP9uAwaOAhv9j9CsI0KKlCjkoX3YH
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1X7ZqP9uAwaOAhv9j9CsI0KKlCjkoX3YH
# To: /content/Animals.zip
# 122MB [00:00, 180MB/s]

# %%
def ynindicator(Y):
  N = len(Y)
  K = len(set(Y))
  I = np.zeros((N, K))
  I[np.arange(N), Y] = 1
  return I

# %%
#Extraindo os arquivos zip e salvando na variavel x
Arq =['Animals.zip']  #importando os arquivos
Image_Size=150
Image_Name=[]  #lista em branco
X_Gray=[]  
for FILE in Arq:
  file_name = zipfile.ZipFile(FILE, 'r')
  file_name.extractall()    #extraindo os arquivos e colocando em uma lista unica com os nomes
  with zipfile.ZipFile(FILE, "r") as f:
      for Name in f.namelist():
          Image_Name.append(Name)
          X_Gray.append(cv2.resize(cv2.imread(Name, 0),(Image_Size,Image_Size))) #passando a imagem para preto e branco e redimensionando

# %%
#Recuperando o nome com 4 primeiras letras
Y_Names = []
for yy in Image_Name:
  Name = yy[0]+yy[1]+yy[2]+yy[3]
  Y_Names.append(Name)  
  #print(y_Names)

# %%
#Plotando algumas imagens em preto e branco com seus respectivos nomes (4 primeiras letras)
num = len(Y_Names)
plt.figure(figsize=(16,16))
for i in range (16) :
  ax = plt.subplot(4,4,i+1)
  kk = random.randrange(num)
  plt.imshow(X_Gray[kk], cmap='gray')
  plt.title(Y_Names[kk])
  plt.axis("off")

# %%
Unique_List = []      #gera uma lista com as classes únicas
for yy in Y_Names:
  if yy not in Unique_List:
    Unique_List.append(yy)

# %%
n = len(Unique_List)  #separa em classes ao inves de nome aparece o índice referente
Y = []
for yy in Y_Names:   #Loop com nome e armazena em y o nome dessas classes unicas com um vetor om os numeros 0, 1, 2,3
  for i in range(n):
    if(yy == Unique_List[i]):
      Y.append(i)

# %%
Unique_List
# Out:
# ['Alpa', 'Not_']

# %%
DATASET_SIZE = len(Y_Names)
Index = range(DATASET_SIZE)
Image_Size = 150
Num_Range = DATASET_SIZE

# %%
#Separando os dados em 80% de treino e 20% de teste e misturando os dados
Index_Train, Index_Test= train_test_split(Index,test_size=0.20, shuffle=True, random_state=3)

# %%
X_Train = []
Y_Train = []
for II in Index_Train:
  Name = Image_Name[II]
  X_Train.append(cv2.resize(cv2.imread(Name),(Image_Size,Image_Size)))
  Y_Train.append(Y[II])

# %%
X_Test= []
Y_Test = []
for II in Index_Test:
  Name = Image_Name[II]
  X_Test.append(cv2.resize(cv2.imread(Name),(Image_Size,Image_Size)))
  Y_Test.append(Y[II])

# %%
X_Train = np.array(X_Train)
Y_Train = np.array(Y_Train)
K = len(set(Y_Train))
X_Train = X_Train.reshape(-1, Image_Size, Image_Size, 3) / 255.0
Y_Train = Y_Train.astype(np.int32)
Y_Train = ynindicator(Y_Train)

X_Test = np.array(X_Test )
Y_Test = np.array(Y_Test)
X_Test = X_Test.reshape(-1, Image_Size, Image_Size, 3) / 255.0
Y_Test = Y_Test.astype(np.int32)
Y_Test = ynindicator(Y_Test)

# %%
# the model will be a sequence of layers

model = Sequential()


# make the CNN
# model.add(Input(shape=(28, 28, 1)))
model.add(Conv2D(input_shape=(Image_Size, Image_Size, 3), filters=32, kernel_size=(3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=64, kernel_size=(3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=128, kernel_size=(3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(units=200))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(units=100))
model.add(Activation('relu'))
model.add(Dense(units=K))
model.add(Activation('softmax'))


# list of losses: https://keras.io/losses/
# list of optimizers: https://keras.io/optimizers/
# list of metrics: https://keras.io/metrics/
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# gives us back a <keras.callbacks.History object at 0x112e61a90>
r = model.fit(X_Train, Y_Train, validation_data = (X_Test,Y_Test), epochs=50, batch_size=32)
print("Returned:", r)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 51s 268ms/step - loss: 8.6206 - accuracy: 0.5298 - val_loss: 0.8176 - val_accuracy: 0.5606
# Epoch 2/50
# 9/9 [==============================] - 1s 71ms/step - loss: 3.7584 - accuracy: 0.5381 - val_loss: 0.8177 - val_accuracy: 0.4394
# Epoch 3/50
# 9/9 [==============================] - 1s 70ms/step - loss: 2.1878 - accuracy: 0.5811 - val_loss: 0.8775 - val_accuracy: 0.5455
# Epoch 4/50
# 9/9 [==============================] - 1s 71ms/step - loss: 1.7797 - accuracy: 0.5896 - val_loss: 0.6605 - val_accuracy: 0.5303
# Epoch 5/50
# 9/9 [==============================] - 1s 71ms/step - loss: 1.4905 - accuracy: 0.6804 - val_loss: 0.7121 - val_accuracy: 0.5758
# Epoch 6/50
# 9/9 [==============================] - 1s 71ms/step - loss: 1.5588 - accuracy: 0.5890 - val_loss: 0.6758 - val_accuracy: 0.5758
# Epoch 7/50
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0507 - accuracy: 0.6050 - val_loss: 0.7933 - val_accuracy: 0.5758
# Epoch 8/50
# 9/9 [==============================] - 1s 72ms/step - loss: 1.1231 - accuracy: 0.6957 - val_loss: 1.1308 - val_accuracy: 0.5606
# Epoch 9/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.8128 - accuracy: 0.7188 - val_loss: 0.6617 - val_accuracy: 0.5758
# Epoch 10/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.6845 - accuracy: 0.7425 - val_loss: 0.6414 - val_accuracy: 0.5758
# Epoch 11/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.7051 - accuracy: 0.7564 - val_loss: 0.7277 - val_accuracy: 0.5606
# Epoch 12/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.5196 - accuracy: 0.8008 - val_loss: 0.9621 - val_accuracy: 0.5606
# Epoch 13/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6121 - accuracy: 0.7354 - val_loss: 0.6767 - val_accuracy: 0.5758
# Epoch 14/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.5687 - accuracy: 0.8017 - val_loss: 0.6282 - val_accuracy: 0.6667
# Epoch 15/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.4190 - accuracy: 0.8350 - val_loss: 0.6160 - val_accuracy: 0.6818
# Epoch 16/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3062 - accuracy: 0.8695 - val_loss: 0.7797 - val_accuracy: 0.5606
# Epoch 17/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3441 - accuracy: 0.8296 - val_loss: 0.6843 - val_accuracy: 0.5606
# Epoch 18/50
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2447 - accuracy: 0.9111 - val_loss: 0.9549 - val_accuracy: 0.4848
# Epoch 19/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2892 - accuracy: 0.8558 - val_loss: 1.2632 - val_accuracy: 0.5606
# Epoch 20/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3166 - accuracy: 0.8560 - val_loss: 0.6447 - val_accuracy: 0.7273
# Epoch 21/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3687 - accuracy: 0.8772 - val_loss: 0.6101 - val_accuracy: 0.7121
# Epoch 22/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2154 - accuracy: 0.9090 - val_loss: 0.7251 - val_accuracy: 0.6364
# Epoch 23/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3892 - accuracy: 0.8727 - val_loss: 1.2133 - val_accuracy: 0.5606
# Epoch 24/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3694 - accuracy: 0.8406 - val_loss: 0.7392 - val_accuracy: 0.6212
# Epoch 25/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2243 - accuracy: 0.9010 - val_loss: 0.8747 - val_accuracy: 0.5758
# Epoch 26/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.2454 - accuracy: 0.8872 - val_loss: 0.8708 - val_accuracy: 0.6364
# Epoch 27/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.1402 - accuracy: 0.9199 - val_loss: 0.7570 - val_accuracy: 0.7273
# Epoch 28/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.1736 - accuracy: 0.9277 - val_loss: 1.1192 - val_accuracy: 0.5909
# Epoch 29/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.1507 - accuracy: 0.9542 - val_loss: 1.0294 - val_accuracy: 0.6061
# Epoch 30/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.1262 - accuracy: 0.9500 - val_loss: 1.8188 - val_accuracy: 0.5606
# Epoch 31/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0955 - accuracy: 0.9531 - val_loss: 1.0388 - val_accuracy: 0.6818
# Epoch 32/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.1760 - accuracy: 0.9271 - val_loss: 1.4905 - val_accuracy: 0.6364
# Epoch 33/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2103 - accuracy: 0.9263 - val_loss: 1.5318 - val_accuracy: 0.5606
# Epoch 34/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.1605 - accuracy: 0.9350 - val_loss: 1.2530 - val_accuracy: 0.6515
# Epoch 35/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.2176 - accuracy: 0.9287 - val_loss: 1.4550 - val_accuracy: 0.6364
# Epoch 36/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.1891 - accuracy: 0.9208 - val_loss: 1.4183 - val_accuracy: 0.6515
# Epoch 37/50
# 9/9 [==============================] - 1s 69ms/step - loss: 0.1168 - accuracy: 0.9624 - val_loss: 1.5080 - val_accuracy: 0.6364
# Epoch 38/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0982 - accuracy: 0.9577 - val_loss: 1.7345 - val_accuracy: 0.6212
# Epoch 39/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.0850 - accuracy: 0.9605 - val_loss: 1.8504 - val_accuracy: 0.6061
# Epoch 40/50
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0517 - accuracy: 0.9779 - val_loss: 1.8772 - val_accuracy: 0.6212
# Epoch 41/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0509 - accuracy: 0.9803 - val_loss: 1.8647 - val_accuracy: 0.6515
# Epoch 42/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2867 - accuracy: 0.9058 - val_loss: 1.8176 - val_accuracy: 0.5909
# Epoch 43/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.1194 - accuracy: 0.9472 - val_loss: 2.6996 - val_accuracy: 0.5606
# Epoch 44/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.1259 - accuracy: 0.9545 - val_loss: 1.9106 - val_accuracy: 0.5758
# Epoch 45/50
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1196 - accuracy: 0.9533 - val_loss: 1.7997 - val_accuracy: 0.5455
# Epoch 46/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0939 - accuracy: 0.9779 - val_loss: 1.6518 - val_accuracy: 0.6061
# Epoch 47/50
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1376 - accuracy: 0.9569 - val_loss: 1.8170 - val_accuracy: 0.6061
# Epoch 48/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.1373 - accuracy: 0.9386 - val_loss: 1.1225 - val_accuracy: 0.7121
# Epoch 49/50
# 9/9 [==============================] - 1s 70ms/step - loss: 0.1233 - accuracy: 0.9468 - val_loss: 1.6143 - val_accuracy: 0.6212
# Epoch 50/50
# 9/9 [==============================] - 1s 71ms/step - loss: 0.1355 - accuracy: 0.9374 - val_loss: 1.2735 - val_accuracy: 0.6818
# Returned: <keras.callbacks.History object at 0x7f3ae0511890>

# %%
# plot some data
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show()

# %%
# plot some data
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
