# %% [markdown]
# <a href="https://colab.research.google.com/github/thessafuzaro/Trabalho_Imagens/blob/main/Recycle_018_Cassificacao_Imagens_Alpaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Segundo Projeto de redes neurais
#Processamento de Imagens
#Aluna: Thessa Fuzaro Mendes
#Data: 03/07/2021

# %%
from matplotlib import pyplot as plt  # para fazer graficos
import numpy as np
import pandas as pd
import cv2  #biblioteca que trabalha com imagens
import random
import zipfile  #para trabalhar com arquivos zip
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# %%
#Importando os arquivos que estão no googledrive
# !gdown --id 1X7ZqP9uAwaOAhv9j9CsI0KKlCjkoX3YH
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1X7ZqP9uAwaOAhv9j9CsI0KKlCjkoX3YH
# To: /content/Animals.zip
# 122MB [00:00, 147MB/s]

# %%
def ynindicator(Y):
  N = len(Y)
  K = len(set(Y))
  I = np.zeros((N, K))
  I[np.arange(N), Y] = 1
  return I

# %%
#Extraindo os arquivos zip e salvando na variavel x
Arq =['Animals.zip']  #importando os arquivos
Image_Size=400
Image_Name=[]  #lista em branco
X_Gray=[]  
X_Original = []
for FILE in Arq:
  file_name = zipfile.ZipFile(FILE, 'r')
  file_name.extractall()    #extraindo os arquivos e colocando em uma lista unica com os nomes
  with zipfile.ZipFile(FILE, "r") as f:
      for Name in f.namelist():
          Image_Name.append(Name)
          X_Original.append(cv2.resize(cv2.cvtColor(cv2.imread(Name),cv2.COLOR_BGR2RGB),(Image_Size,Image_Size)))

# %%
#Recuperando o nome com 4 primeiras letras
Y_Names = []
for yy in Image_Name:
  Name = yy[0]+yy[1]+yy[2]+yy[3]
  Y_Names.append(Name)  
  #print(y_Names)

# %%
#Plotando algumas imagens em preto e branco com seus respectivos nomes (4 primeiras letras)
num = len(Y_Names)
plt.figure(figsize=(16,16))
for i in range (16) :
  ax = plt.subplot(4,4,i+1)
  kk = random.randrange(num)
  plt.imshow(X_Original[kk])
  plt.title(Y_Names[kk])
  plt.axis("off")

# %%
Unique_List = []      #gera uma lista com as classes únicas
for yy in Y_Names:
  if yy not in Unique_List:
    Unique_List.append(yy)

# %%
n = len(Unique_List)  #separa em classes ao inves de nome aparece o índice referente
Y = []
for yy in Y_Names:   #Loop com nome e armazena em y o nome dessas classes unicas com um vetor om os numeros 0, 1, 2,3
  for i in range(n):
    if(yy == Unique_List[i]):
      Y.append(i)

# %%
Unique_List
# Out:
# ['Alpa', 'Not_']

# %%
DATASET_SIZE = len(Y_Names)
Index = range(DATASET_SIZE)
Image_Size = 300
Num_Range = DATASET_SIZE

# %%
#Separando os dados em 80% de treino e 20% de teste e misturando os dados
Index_Train, Index_Test= train_test_split(Index,test_size=0.40, shuffle=True, random_state=3)

# %%
X_Train = []
Y_Train = []
for II in Index_Train:
  Name = Image_Name[II]
  X_Train.append(cv2.resize(cv2.imread(Name),(Image_Size,Image_Size)))
  Y_Train.append(Y[II])

# %%
X_Test= []
Y_Test = []
for II in Index_Test:
  Name = Image_Name[II]
  X_Test.append(cv2.resize(cv2.imread(Name),(Image_Size,Image_Size)))
  Y_Test.append(Y[II])

# %%
X_Train = np.array(X_Train)
Y_Train = np.array(Y_Train)
K = len(set(Y_Train))
X_Train = X_Train.reshape(-1, Image_Size, Image_Size, 3) / 255.0
Y_Train = Y_Train.astype(np.int32)
Y_Train = ynindicator(Y_Train)

X_Test = np.array(X_Test )
Y_Test = np.array(Y_Test)
X_Test = X_Test.reshape(-1, Image_Size, Image_Size, 3) / 255.0
Y_Test = Y_Test.astype(np.int32)
Y_Test = ynindicator(Y_Test)

# %%
# the model will be a sequence of layers

model = Sequential()


# make the CNN
# model.add(Input(shape=(28, 28, 1)))
model.add(Conv2D(input_shape=(Image_Size, Image_Size, 3), filters=32, kernel_size=(3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=64, kernel_size=(3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=128, kernel_size=(3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(units=200))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(units=100))
model.add(Activation('relu'))
model.add(Dense(units=K))
model.add(Activation('softmax'))


# list of losses: https://keras.io/losses/
# list of optimizers: https://keras.io/optimizers/
# list of metrics: https://keras.io/metrics/
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# gives us back a <keras.callbacks.History object at 0x112e61a90>
r = model.fit(X_Train, Y_Train, validation_data = (X_Test,Y_Test), epochs=50, batch_size=32)
print("Returned:", r)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 1s 179ms/step - loss: 0.9945 - accuracy: 0.7857 - val_loss: 0.9471 - val_accuracy: 0.5420
# Epoch 2/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.5869 - accuracy: 0.8622 - val_loss: 1.0610 - val_accuracy: 0.5344
# Epoch 3/50
# 7/7 [==============================] - 1s 146ms/step - loss: 1.0892 - accuracy: 0.8418 - val_loss: 1.9130 - val_accuracy: 0.5344
# Epoch 4/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.7346 - accuracy: 0.8316 - val_loss: 1.2315 - val_accuracy: 0.5420
# Epoch 5/50
# 7/7 [==============================] - 1s 143ms/step - loss: 0.7828 - accuracy: 0.8622 - val_loss: 1.1755 - val_accuracy: 0.5420
# Epoch 6/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.9177 - accuracy: 0.7908 - val_loss: 1.3276 - val_accuracy: 0.5344
# Epoch 7/50
# 7/7 [==============================] - 1s 145ms/step - loss: 1.2089 - accuracy: 0.8010 - val_loss: 0.7902 - val_accuracy: 0.5344
# Epoch 8/50
# 7/7 [==============================] - 1s 145ms/step - loss: 1.2918 - accuracy: 0.7500 - val_loss: 1.3696 - val_accuracy: 0.5267
# Epoch 9/50
# 7/7 [==============================] - 1s 144ms/step - loss: 0.9249 - accuracy: 0.7806 - val_loss: 1.7631 - val_accuracy: 0.5344
# Epoch 10/50
# 7/7 [==============================] - 1s 147ms/step - loss: 0.5635 - accuracy: 0.8214 - val_loss: 0.8747 - val_accuracy: 0.4656
# Epoch 11/50
# 7/7 [==============================] - 1s 144ms/step - loss: 0.7926 - accuracy: 0.8061 - val_loss: 1.3182 - val_accuracy: 0.5267
# Epoch 12/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.8380 - accuracy: 0.7857 - val_loss: 1.3977 - val_accuracy: 0.5344
# Epoch 13/50
# 7/7 [==============================] - 1s 144ms/step - loss: 0.7316 - accuracy: 0.7857 - val_loss: 0.9346 - val_accuracy: 0.5420
# Epoch 14/50
# 7/7 [==============================] - 1s 165ms/step - loss: 0.4645 - accuracy: 0.8520 - val_loss: 0.8216 - val_accuracy: 0.5802
# Epoch 15/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.4957 - accuracy: 0.8827 - val_loss: 0.9024 - val_accuracy: 0.5878
# Epoch 16/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.6211 - accuracy: 0.8878 - val_loss: 0.9566 - val_accuracy: 0.5878
# Epoch 17/50
# 7/7 [==============================] - 1s 148ms/step - loss: 0.2795 - accuracy: 0.9082 - val_loss: 1.3932 - val_accuracy: 0.5344
# Epoch 18/50
# 7/7 [==============================] - 1s 166ms/step - loss: 0.4764 - accuracy: 0.9031 - val_loss: 1.1722 - val_accuracy: 0.5115
# Epoch 19/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.3881 - accuracy: 0.8776 - val_loss: 1.2687 - val_accuracy: 0.4504
# Epoch 20/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.3265 - accuracy: 0.8673 - val_loss: 1.2557 - val_accuracy: 0.4962
# Epoch 21/50
# 7/7 [==============================] - 1s 144ms/step - loss: 0.8455 - accuracy: 0.8673 - val_loss: 1.9269 - val_accuracy: 0.5344
# Epoch 22/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.8185 - accuracy: 0.8214 - val_loss: 1.8635 - val_accuracy: 0.5420
# Epoch 23/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.5137 - accuracy: 0.8878 - val_loss: 1.4552 - val_accuracy: 0.5496
# Epoch 24/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.4223 - accuracy: 0.8724 - val_loss: 1.6173 - val_accuracy: 0.5420
# Epoch 25/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.4209 - accuracy: 0.8827 - val_loss: 1.6797 - val_accuracy: 0.5420
# Epoch 26/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.3780 - accuracy: 0.9082 - val_loss: 1.9214 - val_accuracy: 0.5420
# Epoch 27/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.4197 - accuracy: 0.9031 - val_loss: 1.7167 - val_accuracy: 0.5420
# Epoch 28/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.2739 - accuracy: 0.9286 - val_loss: 1.6453 - val_accuracy: 0.5878
# Epoch 29/50
# 7/7 [==============================] - 1s 143ms/step - loss: 0.2988 - accuracy: 0.9133 - val_loss: 1.5798 - val_accuracy: 0.5649
# Epoch 30/50
# 7/7 [==============================] - 1s 143ms/step - loss: 0.2079 - accuracy: 0.9490 - val_loss: 1.8611 - val_accuracy: 0.5496
# Epoch 31/50
# 7/7 [==============================] - 1s 143ms/step - loss: 0.3186 - accuracy: 0.9439 - val_loss: 2.0740 - val_accuracy: 0.5420
# Epoch 32/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.1141 - accuracy: 0.9592 - val_loss: 1.4057 - val_accuracy: 0.5573
# Epoch 33/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.1406 - accuracy: 0.9490 - val_loss: 1.0629 - val_accuracy: 0.5496
# Epoch 34/50
# 7/7 [==============================] - 1s 143ms/step - loss: 0.2949 - accuracy: 0.9490 - val_loss: 1.6245 - val_accuracy: 0.5649
# Epoch 35/50
# 7/7 [==============================] - 1s 141ms/step - loss: 0.3120 - accuracy: 0.9235 - val_loss: 1.3843 - val_accuracy: 0.5725
# Epoch 36/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.2770 - accuracy: 0.9031 - val_loss: 1.4452 - val_accuracy: 0.5649
# Epoch 37/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.1188 - accuracy: 0.9541 - val_loss: 2.0385 - val_accuracy: 0.5725
# Epoch 38/50
# 7/7 [==============================] - 1s 144ms/step - loss: 0.1380 - accuracy: 0.9439 - val_loss: 2.1449 - val_accuracy: 0.5725
# Epoch 39/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.1694 - accuracy: 0.9541 - val_loss: 1.6641 - val_accuracy: 0.6107
# Epoch 40/50
# 7/7 [==============================] - 1s 147ms/step - loss: 0.0544 - accuracy: 0.9745 - val_loss: 1.6299 - val_accuracy: 0.5725
# Epoch 41/50
# 7/7 [==============================] - 1s 143ms/step - loss: 0.1636 - accuracy: 0.9694 - val_loss: 2.6554 - val_accuracy: 0.5954
# Epoch 42/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.1090 - accuracy: 0.9643 - val_loss: 3.2566 - val_accuracy: 0.5725
# Epoch 43/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.2430 - accuracy: 0.9388 - val_loss: 1.9281 - val_accuracy: 0.5954
# Epoch 44/50
# 7/7 [==============================] - 1s 164ms/step - loss: 0.1223 - accuracy: 0.9694 - val_loss: 1.0082 - val_accuracy: 0.6107
# Epoch 45/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.2153 - accuracy: 0.9388 - val_loss: 1.2743 - val_accuracy: 0.5725
# Epoch 46/50
# 7/7 [==============================] - 1s 147ms/step - loss: 0.2053 - accuracy: 0.9439 - val_loss: 2.2777 - val_accuracy: 0.5344
# Epoch 47/50
# 7/7 [==============================] - 1s 164ms/step - loss: 0.2470 - accuracy: 0.9337 - val_loss: 2.2032 - val_accuracy: 0.5802
# Epoch 48/50
# 7/7 [==============================] - 1s 144ms/step - loss: 0.1635 - accuracy: 0.9592 - val_loss: 1.5861 - val_accuracy: 0.5649
# Epoch 49/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.0713 - accuracy: 0.9745 - val_loss: 1.6969 - val_accuracy: 0.5802
# Epoch 50/50
# 7/7 [==============================] - 1s 141ms/step - loss: 0.0380 - accuracy: 0.9898 - val_loss: 1.7425 - val_accuracy: 0.5802
# Returned: <keras.callbacks.History object at 0x7f479f717cd0>

# %%
# plot some data
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show()

# %%
# plot some data
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
